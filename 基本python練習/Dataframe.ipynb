# %%
import pandas as pd

# %%
#資料索引
data = pd.DataFrame({
    "name":["Amy","KK","Charlies"],
    "salary":[30000,40000,50000]
},index = ['a','b','c'])

# %%
data
# Out:
#        name  salary
# a       Amy   30000
# b        KK   40000
# c  Charlies   50000

# %%
#資料數量
data.size
# Out:
# 6

# %%
data.iloc[1][1]
# Out:
# 40000

# %%
data.loc['c']
# Out:
# name      Charlies
# salary       50000
# Name: c, dtype: object

# %%
names = data['name']
names.str.upper()
# Out:
# a         AMY
# b          KK
# c    CHARLIES
# Name: name, dtype: object

# %%
data
# Out:
#        name  salary
# a       Amy   30000
# b        KK   40000
# c  Charlies   50000

# %%
data['revenue'] = [55,22,33]

# %%
data
# Out:
#        name  salary  revenue
# a       Amy   30000       55
# b        KK   40000       22
# c  Charlies   50000       33

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-3,3,50)
y1=2*x+1
y2=x**2

# %%
plt.plot(x,y1)
plt.plot(x,y2,color = 'red',linewidth = 9,linestyle = '--')
plt.legend(labels=['bbb','aaa'],loc = 'best')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
