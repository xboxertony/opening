# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,50,100)
y = np.linspace(0,50,100)

z = x**2+y**2+5

# %%
X,Y = np.meshgrid(x,y)

# %%
Z = X**2+Y**2+5

# %%
fig = plt.figure()
fig.colorbar(contour, shrink=1.0, aspect=20)

contour = plt.contourf(X,Y,Z,cmap = 'coolwarm_r')

#plt.clabel(contour,fontsize=10,colors = 'black')

# %%
data = np.array(list(zip(X.ravel(),Y.ravel())))

# %%
data
# Out:
# array([[ 0.        ,  0.        ],
#        [ 0.50505051,  0.        ],
#        [ 1.01010101,  0.        ],
#        ...,
#        [48.98989899, 50.        ],
#        [49.49494949, 50.        ],
#        [50.        , 50.        ]])

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.scatter(data[:,0],data[:,1],s=10)

plt.subplot(1,2,2)
contour = plt.contourf(X,Y,Z,cmap = 'cool')
C = plt.contour(X,Y,Z)
plt.clabel(C,inline = True,fontsize=10,colors = 'black')
fig.colorbar(contour,shrink=1,aspect = 20)
