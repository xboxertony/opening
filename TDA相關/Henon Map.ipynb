# %%
x,y,a,b = 0.5,0.5,1.15,0.3
L_x,L_y=[],[]
for i in range(1000):
    #global x,y,a,b
    x_old = x
    y_old = y
    y = b*x_old
    x = 1-a*x_old**2+y_old
    L_x.append(x)
    L_y.append(y)

# %%
import matplotlib.pyplot as plt
plt.scatter(L_x,L_y)
plt.show()
